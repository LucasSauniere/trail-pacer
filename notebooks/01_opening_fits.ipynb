# %%
from trail_pacer.utils import DATA_PATH

from astropy.io import fits

hdul = fits.open(DATA_PATH / "fits" / "Cuges-les-PinsTrailRun20260301090027.fit")
hdul.info()
data = hdul[0].data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from trail_pacer.utils import DATA_PATH
#       2
#       3 from astropy.io import fits
#       4
#
# ModuleNotFoundError: No module named 'trail_pacer'
